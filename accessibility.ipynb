# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import seaborn as sns
import contextily as ctx

# %%
import matplotlib.pyplot as plt

from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
mobility_tried_doubly_un = pd.read_csv("for_luti/results/mobility_tried_doubly_un.csv", index_col=0)

# %%
mobility_tried_doubly_un_for_A = mobility_tried_doubly_un[{'repaired_avg_time','Dest','Orig','QuasiDoublyfitted'}]
mobility_tried_doubly_un_for_A ['pflows/cost'] = mobility_tried_doubly_un_for_A['QuasiDoublyfitted']/ mobility_tried_doubly_un_for_A['repaired_avg_time']
mobility_tried_doubly_un_for_A
# Out:
# /var/folders/21/w5lmmxvj1hq3rngz1m0p7tnm0000gn/T/ipykernel_3492/2782021414.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   mobility_tried_doubly_un_for_A = mobility_tried_doubly_un[{'repaired_avg_time','Dest','Orig','QuasiDoublyfitted'}]
# /var/folders/21/w5lmmxvj1hq3rngz1m0p7tnm0000gn/T/ipykernel_3492/2782021414.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mobility_tried_doubly_un_for_A ['pflows/cost'] = mobility_tried_doubly_un_for_A['QuasiDoublyfitted']/ mobility_tried_doubly_un_for_A['repaired_avg_time']
#         repaired_avg_time  QuasiDoublyfitted  Orig  Dest  pflows/cost
# 0               23.635000                0.0     2     3     0.000000
# ...

# %%
origin_list = pd.read_csv('for_luti/sz_living_working_stats_class_without0 (1).csv')
origin_list
# Out:
#      FID  name     合计     POINT_X    POINT_Y   house_price  class  \
# 0      2   人民桥   4141  114.107222  22.543346  24695.199220      1
# 1      3    红岭   8138  114.106345  22.554773  32797.101560      1
# 2      4    红南   6738  114.102381  22.550613  31337.000000      1
# 3      6    滨苑   5329  114.101974  22.540225  23495.699220      2
# 4      8  桂园老围   6560  114.101407  22.546298  35098.398440      1
# ..   ...   ...    ...         ...        ...           ...    ...
# 572  774    海月  13903  114.241429  22.567262   2207.229981      3
# 573  775    海涛   8511  114.230542  22.551088  13624.599610      3
# 574  777    南坑  10945  114.063741  22.607212  11863.400390      3
# 575  778    红棉   2809  114.175082  22.643314  26895.900390      1
# 576  780    志盛   1445  114.202743  22.652467  19346.800780      2
#
#      living_number  towork_avg_dis  towork_avg_time  towork_ave_spd  \
# 0             2614       12.958879        35.249879        0.488680
# ...

# %%
# for A1

dfsumTij = mobility_tried_doubly_un_for_A.groupby('Orig')['QuasiDoublyfitted'].sum().rename('sumTij').reset_index()
dfsumTij_Cij= mobility_tried_doubly_un_for_A.groupby('Orig')['pflows/cost'].sum().rename('sumTij/Cij').reset_index()
origin_list['A1Doub'] = dfsumTij_Cij['sumTij/Cij'] / dfsumTij['sumTij']
origin_list
# Out:
#      FID  name     合计     POINT_X    POINT_Y   house_price  class  \
# 0      2   人民桥   4141  114.107222  22.543346  24695.199220      1
# 1      3    红岭   8138  114.106345  22.554773  32797.101560      1
# 2      4    红南   6738  114.102381  22.550613  31337.000000      1
# 3      6    滨苑   5329  114.101974  22.540225  23495.699220      2
# 4      8  桂园老围   6560  114.101407  22.546298  35098.398440      1
# ..   ...   ...    ...         ...        ...           ...    ...
# 572  774    海月  13903  114.241429  22.567262   2207.229981      3
# 573  775    海涛   8511  114.230542  22.551088  13624.599610      3
# 574  777    南坑  10945  114.063741  22.607212  11863.400390      3
# 575  778    红棉   2809  114.175082  22.643314  26895.900390      1
# 576  780    志盛   1445  114.202743  22.652467  19346.800780      2
#
#      living_number  towork_avg_dis  towork_avg_time  towork_ave_spd  \
# 0             2614       12.958879        35.249879        0.488680
# ...

# %%
origin_list_tomerge = origin_list[{'FID','A1Doub','house_price'}]
# Out:
# /var/folders/21/w5lmmxvj1hq3rngz1m0p7tnm0000gn/T/ipykernel_3492/191264708.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   origin_list_tomerge = origin_list[{'FID','A1Doub','house_price'}]

# %%
origin_list_tomerge = origin_list_tomerge.rename(columns={'FID':'id'})
origin_list_tomerge
# Out:
#        A1Doub   id   house_price
# 0    0.163220    2  24695.199220
# 1    0.263568    3  32797.101560
# 2    0.240623    4  31337.000000
# 3    0.114082    6  23495.699220
# 4    0.127683    8  35098.398440
# ..        ...  ...           ...
# 572  0.062375  774   2207.229981
# 573  0.136513  775  13624.599610
# 574  0.052660  777  11863.400390
# 575  0.062851  778  26895.900390
# 576  0.057711  780  19346.800780
#
# [577 rows x 3 columns]

# %%
origin_list_tomerge_p = origin_list_tomerge.copy(True)
origin_list_tomerge_p = origin_list_tomerge_p.sort_values(by='A1Doub', ascending=False)
origin_list_tomerge_p.loc[531,'A1Doub'] = 0.959290
origin_list_tomerge_p = origin_list_tomerge_p.sort_values(by='id', ascending=False)
origin_list_tomerge_p
# Out:
#        A1Doub   id   house_price
# 576  0.057711  780  19346.800780
# 575  0.062851  778  26895.900390
# 574  0.052660  777  11863.400390
# 573  0.136513  775  13624.599610
# 572  0.062375  774   2207.229981
# ..        ...  ...           ...
# 4    0.127683    8  35098.398440
# 3    0.114082    6  23495.699220
# 2    0.240623    4  31337.000000
# 1    0.263568    3  32797.101560
# 0    0.163220    2  24695.199220
#
# [577 rows x 3 columns]
